# %% [markdown]
# # HDBSCAN Hyperparameter Tuning
#
# This notebook optimizes HDBSCAN clustering parameters for article summaries using Optuna.
#
# ## TODOs
#
# - use train / xval sets, evaluate in xval, maybe 5 k-fold xvals
# - do longer optuna with a couple hundred tests
# - add params: pca v umap
# - do once with dbscan and once with hdbscan
# - give it 200 test inputs and compare vs a canonical clustering

# %%
import dotenv
from typing import List, Dict, Any, Optional
from collections import Counter
from functools import partial
import os
import glob
import sqlite3
import pickle
import json
from pathlib import Path
from datetime import datetime
import time

import numpy as np
import pandas as pd
import openai
from openai import RateLimitError, APIError

from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.decomposition import TruncatedSVD
import umap
import hdbscan
import optuna

import warnings
warnings.filterwarnings('ignore')

dotenv.load_dotenv()
# Out:
# True

# %%
# Configuration parameters

# Minimum components for dimensionality reduction
# Below 50, clustering becomes unstable for our 3072-dim embeddings
MIN_COMPONENTS = 50

# Number of Optuna optimization trials
# 100 trials takes ~30-45 minutes; increase for better results
N_TRIALS = 100

# Random seed for reproducibility
RANDOM_STATE = 42

# OpenAI embedding model
# text-embedding-3-large: 3072 dims, $0.00013/1K tokens
EMBEDDING_MODEL = "text-embedding-3-large"

# Cache file for embeddings (to avoid regenerating)
EMBEDDINGS_CACHE = "embeddings.pkl"

# %%
# Connect to SQLite and load articles into a DataFrame
# Note: topics field is now available in the articles table
# Consider adding it to this query for topic-aware clustering evaluation

db_path = "../OpenAIAgentsSDK/newsletter_agent.db"
query = """
SELECT *
FROM articles
WHERE short_summary IS NOT NULL and short_summary != '' and content_length > 100
"""

with sqlite3.connect(db_path) as conn:
    headline_df = pd.read_sql_query(query, conn)

print(f"Loaded {len(headline_df)} unique rows with non-null summaries")
headline_df.head()
# Out:
# Loaded 40340 unique rows with non-null summaries
#      id                                          final_url  \
# 0   721  https://www.ft.com/content/ea3d20ed-5b42-45ce-...
# 1   940  https://www.ft.com/content/c4b5153f-be07-454d-...
# 2  1043  https://www.ft.com/content/934cc94b-32c4-497e-...
# 3  1237  https://www.ft.com/content/5f6f78af-aed9-43a5-...
# 4  1238  https://www.ft.com/content/79b53db3-3411-454c-...
#
#                        url    source  \
# 0  https://t.co/bhcd7nguvj  Techmeme
# 1  https://t.co/nn6cRhGN5w  Techmeme
# 2  https://t.co/pdyStQgIsr  Techmeme
# 3  https://t.co/ZF1E09CAyV  Techmeme
# 4  https://t.co/1k60xCOelv  Techmeme
#
#                                                title published rss_summary  \
# 0  A draft proposal outlines the European Commiss...       NaN         NaN
# 1  AstraZeneca signs $555mn AI deal to identify i...       NaN         NaN
# 2  Deloitte says it will partially refund payment...       NaN         NaN
# 3  OpenAI's deals with Nvidia, AMD, Oracle, and o...       NaN         NaN
# 4  Sources: Elon Musk has appointed former Morgan...       NaN         NaN
#
#    isAI status                                          html_path  ...  \
# 0     1    200  download/html/A_draft_proposal_outlines_the_Eu...  ...
# 1     1    200  download/html/AstraZeneca_signs__555mn_AI_deal...  ...
# 2     1    200  download/html/Deloitte_says_it_will_partially_...  ...
# 3     1    200  download/html/OpenAI_s_deals_with_Nvidia__AMD_...  ...
# 4     1    200  download/html/Sources__Elon_Musk_has_appointed...  ...
#
#                                              summary  \
# 0  - The EU is developing a new AI strategy aimed...
# 1  - AstraZeneca has entered into a $555 million ...
# 2  - Deloitte issued a refund to the Australian g...
# 3  - OpenAI has secured computing deals valued at...
# 4  - Elon Musk appoints Anthony Armstrong, a form...
#
#                                        short_summary  \
# 0  A draft European Commission proposal, to be pr...
# 1  AstraZeneca has signed a $555 million deal to ...
# 2  Deloitte will partially refund payment for an ...
# 3  OpenAI has secured computing deals worth over ...
# 4  Sources say Elon Musk has appointed former Mor...
#
#                                          description    rating cluster_label  \
# 0  Brussels to unveil plan targeting digital sove...  6.231039
# 1  Pharmaceutical company is latest to invest in ...  6.352663
# 2  Big Four firm will repay final instalment afte...  6.393448
# 3  Partners including Nvidia, AMD and Oracle have...  6.510267
# 4  Anthony Armstrong will take over financial man...  6.515726
#
#    domain        site_name reputation date topics
# 0  ft.com  Financial Times        5.0  NaN    NaN
# 1  ft.com  Financial Times        5.0  NaN    NaN
# 2  ft.com  Financial Times        5.0  NaN    NaN
# 3  ft.com  Financial Times        5.0  NaN    NaN
# 4  ft.com  Financial Times        5.0  NaN    NaN
#
# [5 rows x 23 columns]

# %%
headline_df['topics']
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#                                ...
# 40335    Investment Strategies,AI Compute,Semiconductor...
# 40336    Stocks,Magnificent Seven,Taiwan Semiconductor ...
# 40337    Startups,Funding,AI Platform,Cryptocurrency,SE...
# 40338             Oracle,Stock Valuation,AI Infrastructure
# 40339    CoreWeave,AI Data Centers,Stocks,Nvidia,Infras...
# Name: topics, Length: 40340, dtype: str

# %%
from do_cluster import _create_short_summary

# def get_input_text(row):
#     retval = ""
#     if pd.notna(row['short_summary']) and len(str(row['short_summary'])):
#         short_summary = str(row['short_summary']).strip()
#         retval += short_summary
#         topics_list = row['topics']
#         topics = str(topics_list).strip() if topics_list else ""
#         if topics:
#             retval += f" Topics: {topics}"
#     return retval

headline_df['input_text'] = headline_df.apply(_create_short_summary, axis=1)

# %%
headline_df.iloc[-1].input_text
# delete cache embeddings.pkl
# Out:
# 'CoreWeave reported $2.1 billion Q1 2026 revenue, up 112%, with a $99.4 billion backlog. Topics: CoreWeave,AI Data Centers,Stocks,Nvidia,Infrastructure'

# %%
min(headline_df["input_text"].str.len())
# Out:
# 35

# %%
headline_df
# Out:
#           id                                          final_url  \
# 0        721  https://www.ft.com/content/ea3d20ed-5b42-45ce-...
# 1        940  https://www.ft.com/content/c4b5153f-be07-454d-...
# 2       1043  https://www.ft.com/content/934cc94b-32c4-497e-...
# 3       1237  https://www.ft.com/content/5f6f78af-aed9-43a5-...
# 4       1238  https://www.ft.com/content/79b53db3-3411-454c-...
# ...      ...                                                ...
# 40335  49262  https://www.thestreet.com/crypto/markets/opena...
# 40336  49263  https://www.fool.com/investing/2026/05/20/is-b...
# 40337  49264  https://www.globenewswire.com/news-release/202...
# 40338  49265  https://www.fool.com/investing/2026/05/20/is-t...
# 40339  49266  https://www.fool.com/investing/2026/05/18/this...
#
#                                                      url     source  \
# 0                                https://t.co/bhcd7nguvj   Techmeme
# 1                                https://t.co/nn6cRhGN5w   Techmeme
# 2                                https://t.co/pdyStQgIsr   Techmeme
# 3                                https://t.co/ZF1E09CAyV   Techmeme
# 4                                https://t.co/1k60xCOelv   Techmeme
# ...                                                  ...        ...
# 40335  https://finance.yahoo.com/markets/crypto/artic...  Feedly AI
# 40336  https://finance.yahoo.com/markets/stocks/artic...  Feedly AI
# 40337  https://www.globenewswire.com/news-release/202...    NewsAPI
# 40338  https://www.fool.com/investing/2026/05/20/is-t...  Feedly AI
# 40339  https://www.fool.com/investing/2026/05/18/this...  Feedly AI
#
#                                                    title  \
# 0      A draft proposal outlines the European Commiss...
# 1      AstraZeneca signs $555mn AI deal to identify i...
# 2      Deloitte says it will partially refund payment...
# 3      OpenAI's deals with Nvidia, AMD, Oracle, and o...
# 4      Sources: Elon Musk has appointed former Morgan...
# ...                                                  ...
# 40335  OpenAI whistleblower ditches Nvidia, AMD for c...
# 40336  Is Billionaire Michael Platt Souring on the Ma...
# 40337  Sertexity Labs Inc. Files Form D With SEC for ...
# 40338  Is This AI Stock a Buy at 24 Times Earnings --...
# 40339  This Nvidia-BackedArtificial Intelligence(AI) ...
#
#                        published rss_summary  isAI status  \
# 0                            NaN         NaN     1    200
# 1                            NaN         NaN     1    200
# 2                            NaN         NaN     1    200
# 3                            NaN         NaN     1    200
# 4                            NaN         NaN     1    200
# ...                          ...         ...   ...    ...
# 40335                        NaN         NaN     1    200
# 40336                        NaN         NaN     1    200
# 40337  2026-05-19T08:47:00+00:00         NaN     1    200
# 40338                        NaN         NaN     1    200
# 40339                        NaN         NaN     1    200
#
#                                                html_path  ...  \
# 0      download/html/A_draft_proposal_outlines_the_Eu...  ...
# 1      download/html/AstraZeneca_signs__555mn_AI_deal...  ...
# 2      download/html/Deloitte_says_it_will_partially_...  ...
# 3      download/html/OpenAI_s_deals_with_Nvidia__AMD_...  ...
# 4      download/html/Sources__Elon_Musk_has_appointed...  ...
# ...                                                  ...  ...
# 40335  download/html/OpenAI_whistleblower_ditches_Nvi...  ...
# 40336  download/html/Is_Billionaire_Michael_Platt_Sou...  ...
# 40337  download/html/Sertexity_Labs_Inc._Files_Form_D...  ...
# 40338  download/html/Is_This_AI_Stock_a_Buy_at_24_Tim...  ...
# 40339  download/html/This_Nvidia-BackedArtificial_Int...  ...
#
#                                            short_summary  \
# 0      A draft European Commission proposal, to be pr...
# 1      AstraZeneca has signed a $555 million deal to ...
# 2      Deloitte will partially refund payment for an ...
# 3      OpenAI has secured computing deals worth over ...
# 4      Sources say Elon Musk has appointed former Mor...
# ...                                                  ...
# 40335  Whistleblower Leopold Aschenbrenner's fund bet...
# 40336  Michael Platt closed positions in Nvidia, Micr...
# 40337  Sertexity Labs filed a Form D with the SEC for...
# 40338  Oracle stock fell 43% from highs, trading at 2...
# 40339  CoreWeave reported $2.1 billion Q1 2026 revenu...
#
#                                              description    rating  \
# 0      Brussels to unveil plan targeting digital sove...  6.231039
# 1      Pharmaceutical company is latest to invest in ...  6.352663
# 2      Big Four firm will repay final instalment afte...  6.393448
# 3      Partners including Nvidia, AMD and Oracle have...  6.510267
# 4      Anthony Armstrong will take over financial man...  6.515726
# ...                                                  ...       ...
# 40335  Leopold Aschenbrenner is putting serious money...  3.639900
# 40336                    Should you follow Platt's lead?  1.629094
# 40337  MIAMI, May  19, 2026  (GLOBE NEWSWIRE) -- Sert...  0.751208
# 40338  Oracle stock has pulled back substantially fro...  1.741431
# 40339  CoreWeave stock pulled back following its late...  4.080158
#
#                                  cluster_label             domain  \
# 0                                                          ft.com
# 1                                                          ft.com
# 2                                                          ft.com
# 3                                                          ft.com
# 4                                                          ft.com
# ...                                        ...                ...
# 40335             Nvidia's AI Investment Spree      thestreet.com
# 40336                                    Other           fool.com
# 40337  AI Startups Secure Major Funding Rounds  globenewswire.com
# 40338                                    Other           fool.com
# 40339                                    Other           fool.com
#
#              site_name  reputation                              date  \
# 0      Financial Times         5.0                               NaN
# 1      Financial Times         5.0                               NaN
# 2      Financial Times         5.0                               NaN
# 3      Financial Times         5.0                               NaN
# 4      Financial Times         5.0                               NaN
# ...                ...         ...                               ...
# 40335       The Street         0.0  2026-05-20T13:41:28.058315+00:00
# 40336  The Motley Fool        -1.0  2026-05-20T13:41:28.058315+00:00
# 40337   Globe Newswire         0.0  2026-05-20T13:41:28.058315+00:00
# 40338  The Motley Fool        -1.0  2026-05-20T13:41:28.058315+00:00
# 40339  The Motley Fool        -1.0  2026-05-20T13:41:28.058315+00:00
#
#                                                   topics  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40335  Investment Strategies,AI Compute,Semiconductor...
# 40336  Stocks,Magnificent Seven,Taiwan Semiconductor ...
# 40337  Startups,Funding,AI Platform,Cryptocurrency,SE...
# 40338           Oracle,Stock Valuation,AI Infrastructure
# 40339  CoreWeave,AI Data Centers,Stocks,Nvidia,Infras...
#
#                                               input_text
# 0      A draft European Commission proposal, to be pr...
# 1      AstraZeneca has signed a $555 million deal to ...
# 2      Deloitte will partially refund payment for an ...
# 3      OpenAI has secured computing deals worth over ...
# 4      Sources say Elon Musk has appointed former Mor...
# ...                                                  ...
# 40335  Whistleblower Leopold Aschenbrenner's fund bet...
# 40336  Michael Platt closed positions in Nvidia, Micr...
# 40337  Sertexity Labs filed a Form D with the SEC for...
# 40338  Oracle stock fell 43% from highs, trading at 2...
# 40339  CoreWeave reported $2.1 billion Q1 2026 revenu...
#
# [40340 rows x 24 columns]

# %%
headline_df=headline_df[-20000:]

# %%
# Save DataFrame for future reference
headline_df.to_pickle("headline_df.pkl")

# %%
# get embeddings
# Initialize the OpenAI client
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise ValueError("OPENAI_API_KEY environment variable not set")
client = openai.OpenAI(api_key=api_key)

def get_embeddings(
    texts: List[str],
    model: str = EMBEDDING_MODEL,
    batch_size: int = 200,
    max_retries: int = 3
) -> np.ndarray:
    """
    Generate embeddings for a list of texts with error handling and retry logic.
    
    Args:
        texts: List of text strings to embed
        model: OpenAI embedding model name
        batch_size: Number of texts per API call
        max_retries: Maximum retry attempts for failed API calls
    
    Returns:
        NumPy array of embeddings (n_texts, embedding_dim)
    """
    all_embeddings = []
    
    for i in range(0, len(texts), batch_size):
        batch = texts[i : i + batch_size]
        
        for attempt in range(max_retries):
            try:
                resp = client.embeddings.create(model=model, input=batch)
                batch_embeddings = [d.embedding for d in resp.data]
                all_embeddings.extend(batch_embeddings)
                
                # Progress indicator every 10 batches
                if (i // batch_size) % 10 == 0:
                    print(f"Processed {i + len(batch)}/{len(texts)} texts...")
                break
                
            except RateLimitError:
                wait_time = 2 ** attempt  # Exponential backoff
                print(f"⚠️  Rate limit hit. Waiting {wait_time}s before retry {attempt+1}/{max_retries}")
                time.sleep(wait_time)
                
            except APIError as e:
                if attempt == max_retries - 1:
                    print(f"❌ API error after {max_retries} attempts: {e}")
                    raise
                print(f"⚠️  API error (attempt {attempt+1}): {e}. Retrying...")
                time.sleep(1)
                
    return np.array(all_embeddings)

# Check if cached embeddings exist
if Path(EMBEDDINGS_CACHE).exists():
    print(f"Loading cached embeddings from {EMBEDDINGS_CACHE}")
    with open(EMBEDDINGS_CACHE, 'rb') as f:
        cache = pickle.load(f)
        if cache['texts'] == headline_df["input_text"].tolist():
            embeddings_array = cache['embeddings']
            print(f"✓ Loaded {len(embeddings_array)} cached embeddings")
        else:
            print("⚠️  Cache invalid (different texts), regenerating embeddings")
            embeddings_array = get_embeddings(headline_df["input_text"].tolist())
            with open(EMBEDDINGS_CACHE, 'wb') as f:
                pickle.dump({'texts': headline_df["input_text"].tolist(), 
                           'embeddings': embeddings_array}, f)
            print(f"✓ Cached embeddings to {EMBEDDINGS_CACHE}")
else:
    print("Generating embeddings (this may take a while)...")
    embeddings_array = get_embeddings(headline_df["input_text"].tolist())
    # Cache for future runs
    with open(EMBEDDINGS_CACHE, 'wb') as f:
        pickle.dump({'texts': headline_df["input_text"].tolist(), 
                   'embeddings': embeddings_array}, f)
    print(f"✓ Cached embeddings to {EMBEDDINGS_CACHE}")

print(f"Embeddings shape: {embeddings_array.shape}")
# Out:
# Generating embeddings (this may take a while)...
# Processed 200/20000 texts...
# Processed 2200/20000 texts...
# Processed 4200/20000 texts...
# Processed 6200/20000 texts...
# Processed 8200/20000 texts...
# Processed 10200/20000 texts...
# Processed 12200/20000 texts...
# Processed 14200/20000 texts...
# Processed 16200/20000 texts...
# Processed 18200/20000 texts...
# ✓ Cached embeddings to embeddings.pkl
# Embeddings shape: (20000, 3072)

# %%
def calculate_clustering_metrics(
    embeddings_array: np.ndarray,
    labels: np.ndarray,
    clusterer: Optional[hdbscan.HDBSCAN] = None
) -> Dict[str, Any]:
    """
    Calculate various clustering quality metrics for HDBSCAN results.
    
    Args:
        embeddings_array: Original normalized embeddings used for clustering
        labels: Cluster labels from HDBSCAN
        clusterer: Optional HDBSCAN clusterer object
    
    Returns:
        Dictionary of clustering metrics
    """
    # Filter out noise points (-1 labels) for some metrics
    non_noise_mask = labels != -1
    non_noise_embeddings = embeddings_array[non_noise_mask]
    non_noise_labels = labels[non_noise_mask]
    
    metrics = {}
    
    # Basic cluster statistics
    unique_labels = set(labels)
    n_clusters = len(unique_labels) - (1 if -1 in unique_labels else 0)
    n_noise = np.sum(labels == -1)
    
    metrics['n_clusters'] = n_clusters
    metrics['n_noise_points'] = n_noise
    metrics['noise_ratio'] = n_noise / len(labels)
    
    # Cluster size distribution
    cluster_sizes = Counter(labels[labels != -1])
    if cluster_sizes:
        metrics['avg_cluster_size'] = np.mean(list(cluster_sizes.values()))
        metrics['std_cluster_size'] = np.std(list(cluster_sizes.values()))
        metrics['min_cluster_size'] = min(cluster_sizes.values())
        metrics['max_cluster_size'] = max(cluster_sizes.values())
    
    # Skip other metrics if we have too few clusters or too much noise
    if n_clusters < 2 or len(non_noise_labels) < 2:
        print("Warning: Too few clusters or too much noise for some metrics")
        return metrics
    
    # HDBSCAN-specific metrics
    if clusterer is not None:
        try:
            # Validity index (HDBSCAN's internal metric)
            validity_idx = hdbscan.validity.validity_index(
                embeddings_array, labels, metric='euclidean'
            )
            metrics['hdbscan_validity_index'] = validity_idx
        except Exception as e:
            print(f"Could not compute HDBSCAN validity index: {e}")
        
        # Cluster persistence (stability)
        if hasattr(clusterer, 'cluster_persistence_'):
            metrics['cluster_persistence'] = clusterer.cluster_persistence_
    
    # Scikit-learn clustering metrics (excluding noise points)
    try:
        # Silhouette Score (higher is better, range [-1, 1])
        sil_score = silhouette_score(non_noise_embeddings, non_noise_labels, metric='euclidean')
        metrics['silhouette_score'] = sil_score
        
        # Calinski-Harabasz Index (higher is better)
        ch_score = calinski_harabasz_score(non_noise_embeddings, non_noise_labels)
        metrics['calinski_harabasz_score'] = ch_score
        
        # Davies-Bouldin Index (lower is better)
        db_score = davies_bouldin_score(non_noise_embeddings, non_noise_labels)
        metrics['davies_bouldin_score'] = db_score
        
    except Exception as e:
        print(f"Could not compute sklearn metrics: {e}")
    
    # Custom composite score balancing cluster quality
    if 'silhouette_score' in metrics and 'hdbscan_validity_index' in metrics and n_clusters > 0:
        composite_score = (
            0.5 * max(metrics.get('silhouette_score', 0), 0) +  # Quality component
            0.5 * max(metrics.get('hdbscan_validity_index', 0), 0)
        )
        metrics['composite_score'] = composite_score
    
    return metrics

def print_clustering_summary(metrics: Dict[str, Any]) -> None:
    """Print a nice summary of clustering metrics."""
    print("=== Clustering Quality Metrics ===")
    print(f"Number of clusters: {metrics.get('n_clusters', 'N/A')}")
    print(f"Noise points: {metrics.get('n_noise_points', 'N/A')} ({metrics.get('noise_ratio', 0):.1%})")
    
    if 'avg_cluster_size' in metrics:
        print(f"Average cluster size: {metrics['avg_cluster_size']:.1f} ± {metrics.get('std_cluster_size', 0):.1f}")
        print(f"Cluster size range: {metrics.get('min_cluster_size', 'N/A')} - {metrics.get('max_cluster_size', 'N/A')}")
    
    print("=== Quality Scores ===")
    if 'silhouette_score' in metrics:
        print(f"Silhouette Score: {metrics['silhouette_score']:.3f} (higher is better)")
    if 'calinski_harabasz_score' in metrics:
        print(f"Calinski-Harabasz Score: {metrics['calinski_harabasz_score']:.1f} (higher is better)")
    if 'davies_bouldin_score' in metrics:
        print(f"Davies-Bouldin Score: {metrics['davies_bouldin_score']:.3f} (lower is better)")
    if 'hdbscan_validity_index' in metrics:
        print(f"HDBSCAN Validity Index: {metrics['hdbscan_validity_index']:.3f}")
    if 'composite_score' in metrics:
        print(f"Composite Score: {metrics['composite_score']:.3f} (higher is better)")
    print()

# %%
def umap_objective(trial: optuna.Trial, embeddings_array: np.ndarray) -> float:
    """
    Optuna objective function to optimize HDBSCAN hyperparameters jointly with UMAP.
    
    Args:
        trial: Optuna trial object
        reduced_embeddings: Pre-reduced embeddings
    
    Returns:
        Negative composite score (Optuna minimizes, we want to maximize)
    """
    # UMAP hyperparameters to optimize
    
    n_components = trial.suggest_int('n_components', 10, 500)
    n_neighbors = trial.suggest_int('n_neighbors', 10, 50)
    min_dist = trial.suggest_float('min_dist', 0.0, 0.5)

    reducer = umap.UMAP(
        n_components=n_components,
        n_neighbors=n_neighbors,
        min_dist=min_dist,
        random_state=RANDOM_STATE
    )
    reduced_embeddings = reducer.fit_transform(embeddings_array).astype(np.float64)

    # HDBSCAN hyperparameters to optimize
    min_cluster_size = trial.suggest_int('min_cluster_size', 2, 10)
    min_samples = trial.suggest_int('min_samples', 1, min_cluster_size)
            
    try:
        # core_dist_n_jobs=1 prevents nested joblib parallelism that deadlocks on macOS
        clusterer = hdbscan.HDBSCAN(
            min_cluster_size=min_cluster_size,
            min_samples=min_samples,
            metric="euclidean",
            cluster_selection_method="eom",
            core_dist_n_jobs=1,
        )
        
        labels = clusterer.fit_predict(reduced_embeddings)
        
        # Calculate metrics
        metrics = calculate_clustering_metrics(reduced_embeddings, labels, clusterer)
        
        # Return negative composite score (Optuna minimizes)
        composite_score = metrics.get('composite_score', -1.0)
        
        # Penalize if no valid clusters found or too much noise
        if metrics.get('n_clusters', 0) < 2 or metrics.get('noise_ratio', 1.0) > 0.8:
            composite_score = -1.0
            
        return -composite_score
        
    except Exception as e:
        print(f"Error in trial {trial.number}: {e}")
        return 1.0  # Bad score for failed trials

# %%
# min_cluster_size:   9
# min_samples:        8
# n_components:       690

# %%
n_components=370
n_neighbors=11
min_dist=0.0003455236416162778

reducer = umap.UMAP(
    n_components=n_components,
    n_neighbors=n_neighbors,
    min_dist=min_dist,
    random_state=RANDOM_STATE
)
reduced_embeddings = reducer.fit_transform(embeddings_array).astype(np.float64)

min_cluster_size=8
min_samples= 7

clusterer = hdbscan.HDBSCAN(
    min_cluster_size=min_cluster_size,
    min_samples=min_samples,
    metric="euclidean",
    cluster_selection_method="eom",
    core_dist_n_jobs=1,
)
reduced_embeddings = reducer.fit_transform(embeddings_array).astype(np.float64)


reduced_embeddings = umap_reducer.fit_transform(embeddings_array).astype(np.float64)

# %%
best_labels = clusterer.fit_predict(reduced_embeddings)

best_metrics = calculate_clustering_metrics(reduced_embeddings, best_labels, clusterer)

print_clustering_summary(best_metrics)
# Out:
# === Clustering Quality Metrics ===
# Number of clusters: 567
# Noise points: 5828 (29.1%)
# Average cluster size: 25.0 ± 25.1
# Cluster size range: 8 - 307
# === Quality Scores ===
# Silhouette Score: 0.672 (higher is better)
# Calinski-Harabasz Score: 18859.5 (higher is better)
# Davies-Bouldin Score: 0.396 (lower is better)
# HDBSCAN Validity Index: 0.453
# Composite Score: 0.562 (higher is better)

# %%
with open('umap_reducer.pkl', 'wb') as f:
    pickle.dump(reducer, f)
print("✓ Saved UMAP reducer to umap_reducer.pkl")
# Out:
# ✓ Saved UMAP reducer to umap_reducer.pkl

# %%
n_jobs=1
n_trials=N_TRIALS
timeout=None
print(f"Starting optimization with {n_trials} trials, {n_jobs} parallel jobs...")
print(f"Original embedding shape: {embeddings_array.shape}")

# Create study
study = optuna.create_study(
    direction='minimize',  # We return negative composite score
    sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE),
    pruner=optuna.pruners.MedianPruner(n_startup_trials=10)
)

# Use partial instead of lambda (picklable, works with n_jobs)
# n_jobs uses threading; deadlock is avoided by core_dist_n_jobs=1 in HDBSCAN
objective = partial(umap_objective, embeddings_array=embeddings_array)

study.optimize(
    objective,
    n_trials=n_trials,
    # n_jobs=n_jobs,
    timeout=timeout,
    show_progress_bar=True
)

# Get best parameters
best_params = study.best_params
best_score = -study.best_value  # Convert back to positive

print(f"\nOptimization completed!")
print(f"Best composite score: {best_score:.4f}")
print(f"Best parameters: {best_params}")

# Test best parameters
print(f"\n=== Results with Best Parameters ===")

# gave an error

best_reducer = umap.UMAP(
    n_components=best_params['n_components'],
    n_neighbors=best_params['n_neighbors'],
    min_dist=min_dist,
    random_state=RANDOM_STATE
)
best_embeddings = reducer.fit_transform(embeddings_array).astype(np.float64)

best_clusterer = hdbscan.HDBSCAN(
    min_cluster_size=best_params['min_cluster_size'],
    min_samples=best_params['min_samples'],
    metric="euclidean",
    cluster_selection_method="eom",
    core_dist_n_jobs=1,
)

best_labels = best_clusterer.fit_predict(best_embeddings)
best_metrics = calculate_clustering_metrics(best_embeddings, best_labels, best_clusterer)

print_clustering_summary(best_metrics)

# Save results automatically
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
results_file = f"optimization_results_{timestamp}.json"

results_summary = {
    'timestamp': timestamp,
    'best_params': best_params,
    'best_score': float(best_score),
    'best_metrics': {k: float(v) if isinstance(v, (int, float, np.number)) else v 
                     for k, v in best_metrics.items() 
                     if isinstance(v, (int, float, np.number))},
    'n_trials': n_trials,
    'config': {
        'MIN_COMPONENTS': MIN_COMPONENTS,
        'N_TRIALS': N_TRIALS,
        'EMBEDDING_MODEL': EMBEDDING_MODEL,
        'n_samples': len(embeddings_array)
    }
}

with open(results_file, 'w') as f:
    json.dump(results_summary, f, indent=2)
    
print(f"\n✓ Results saved to {results_file}\n")
# Out:
# [I 2026-05-21 06:53:16,335] A new study created in memory with name: no-name-93464d85-93bc-4e29-9d3f-32ff3243ec55
# Starting optimization with 100 trials, 1 parallel jobs...
# Original embedding shape: (20000, 3072)
#   0%|          | 0/100 [00:00<?, ?it/s]
# [W 2026-05-21 06:54:18,543] Trial 0 failed with parameters: {'n_components': 193, 'n_neighbors': 48, 'min_dist': 0.36599697090570255} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/asdk/lib/python3.11/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/var/folders/6d/3xz907yn5ylg43s2vlnnzptr0000gn/T/ipykernel_90462/1013532180.py", line 24, in umap_objective
#     reduced_embeddings = reducer.fit_transform(embeddings_array).astype(np.float64)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/asdk/lib/python3.11/site-packages/umap/umap_.py", line 2934, in fit_transform
#     self.fit(X, y, ensure_all_finite, **kwargs)
#   File "/opt/anaconda3/envs/asdk/lib/python3.11/site-packages/umap/umap_.py", line 2817, in fit
#     self.embedding_, aux_data = self._fit_embed_data(
#                                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/asdk/lib/python3.11/site-packages/umap/umap_.py", line 2871, in _fit_embed_data
#     return simplicial_set_embedding(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/asdk/lib/python3.11/site-packages/umap/umap_.py", line 1195, in simplicial_set_embedding
#     embedding = optimize_layout_euclidean(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/asdk/lib/python3.11/site-packages/umap/layouts.py", line 401, in optimize_layout_euclidean
#     optimize_fn(
# KeyboardInterrupt
# [W 2026-05-21 06:54:18,547] Trial 0 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 18
#      14 # Use partial instead of lambda (picklable, works with n_jobs)
#      15 # n_jobs uses threading; deadlock is avoided by core_dist_n_jobs=1 in HDBSCAN
#      16 objective = partial(umap_objective, embeddings_array=embeddings_array)
# ---> 18 study.optimize(
#      19     objective,
#      20     n_trials=n_trials,
#      21     # n_jobs=n_jobs,
#      22     timeout=timeout,
#      23     show_progress_bar=True
#      24 )
#      26 # Get best parameters
#      27 best_params = study.best_params
#
# File /opt/anaconda3/envs/asdk/lib/python3.11/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File /opt/anaconda3/envs/asdk/lib/python3.11/site-packages/optuna/study/_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File /opt/anaconda3/envs/asdk/lib/python3.11/site-packages/optuna/study/_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File /opt/anaconda3/envs/asdk/lib/python3.11/site-packages/optuna/study/_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File /opt/anaconda3/envs/asdk/lib/python3.11/site-packages/optuna/study/_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# Cell In[17], line 24, in umap_objective(trial, embeddings_array)
#      16 min_dist = trial.suggest_float('min_dist', 0.0, 0.5)
#      18 reducer = umap.UMAP(
#      19     n_components=n_components,
#      20     n_neighbors=n_neighbors,
#      21     min_dist=min_dist,
#      22     random_state=RANDOM_STATE
#      23 )
# ---> 24 reduced_embeddings = reducer.fit_transform(embeddings_array).astype(np.float64)
#      26 # HDBSCAN hyperparameters to optimize
#      27 min_cluster_size = trial.suggest_int('min_cluster_size', 2, 10)
#
# File /opt/anaconda3/envs/asdk/lib/python3.11/site-packages/umap/umap_.py:2934, in UMAP.fit_transform(self, X, y, ensure_all_finite, **kwargs)
#    2896 def fit_transform(self, X, y=None, ensure_all_finite=True, **kwargs):
#    2897     """Fit X into an embedded space and return that transformed
#    2898     output.
#    2899
#    (...)   2932         Local radii of data points in the embedding (log-transformed).
#    2933     """
# -> 2934     self.fit(X, y, ensure_all_finite, **kwargs)
#    2935     if self.transform_mode == "embedding":
#    2936         if self.output_dens:
#
# File /opt/anaconda3/envs/asdk/lib/python3.11/site-packages/umap/umap_.py:2817, in UMAP.fit(self, X, y, ensure_all_finite, **kwargs)
#    2813 if self.transform_mode == "embedding":
#    2814     epochs = (
#    2815         self.n_epochs_list if self.n_epochs_list is not None else self.n_epochs
#    2816     )
# -> 2817     self.embedding_, aux_data = self._fit_embed_data(
#    2818         self._raw_data[index],
#    2819         epochs,
#    2820         init,
#    2821         random_state,  # JH why raw data?
#    2822         **kwargs,
#    2823     )
#    2825     if self.n_epochs_list is not None:
#    2826         if "embedding_list" not in aux_data:
#
# File /opt/anaconda3/envs/asdk/lib/python3.11/site-packages/umap/umap_.py:2871, in UMAP._fit_embed_data(self, X, n_epochs, init, random_state, **kwargs)
#    2866 def _fit_embed_data(self, X, n_epochs, init, random_state, **kwargs):
#    2867     """A method wrapper for simplicial_set_embedding that can be
#    2868     replaced by subclasses. Arbitrary keyword arguments can be passed
#    2869     through .fit() and .fit_transform().
#    2870     """
# -> 2871     return simplicial_set_embedding(
#    2872         X,
#    2873         self.graph_,
#    2874         self.n_components,
#    2875         self._initial_alpha,
#    2876         self._a,
#    2877         self._b,
#    2878         self.repulsion_strength,
#    2879         self.negative_sample_rate,
#    2880         n_epochs,
#    2881         init,
#    2882         random_state,
#    2883         self._input_distance_func,
#    2884         self._metric_kwds,
#    2885         self.densmap,
#    2886         self._densmap_kwds,
#    2887         self.output_dens,
#    2888         self._output_distance_func,
#    2889         self._output_metric_kwds,
#    2890         self.output_metric in ("euclidean", "l2"),
#    2891         self.random_state is None,
#    2892         self.verbose,
#    2893         tqdm_kwds=self.tqdm_kwds,
#    2894     )
#
# File /opt/anaconda3/envs/asdk/lib/python3.11/site-packages/umap/umap_.py:1195, in simplicial_set_embedding(data, graph, n_components, initial_alpha, a, b, gamma, negative_sample_rate, n_epochs, init, random_state, metric, metric_kwds, densmap, densmap_kwds, output_dens, output_metric, output_metric_kwds, euclidean_output, parallel, verbose, tqdm_kwds)
#    1188 embedding = (
#    1189     10.0
#    1190     * (embedding - np.min(embedding, 0))
#    1191     / (np.max(embedding, 0) - np.min(embedding, 0))
#    1192 ).astype(np.float32, order="C")
#    1194 if euclidean_output:
# -> 1195     embedding = optimize_layout_euclidean(
#    1196         embedding,
#    1197         embedding,
#    1198         head,
#    1199         tail,
#    1200         n_epochs,
#    1201         n_vertices,
#    1202         epochs_per_sample,
#    1203         a,
#    1204         b,
#    1205         rng_state,
#    1206         gamma,
#    1207         initial_alpha,
#    1208         negative_sample_rate,
#    1209         parallel=parallel,
#    1210         verbose=verbose,
#    1211         densmap=densmap,
#    1212         densmap_kwds=densmap_kwds,
#    1213         tqdm_kwds=tqdm_kwds,
#    1214         move_other=True,
#    1215     )
#    1216 else:
#    1217     embedding = optimize_layout_generic(
#    1218         embedding,
#    1219         embedding,
#    (...)   1235         move_other=True,
#    1236     )
#
# File /opt/anaconda3/envs/asdk/lib/python3.11/site-packages/umap/layouts.py:401, in optimize_layout_euclidean(head_embedding, tail_embedding, head, tail, n_epochs, n_vertices, epochs_per_sample, a, b, rng_state, gamma, initial_alpha, negative_sample_rate, parallel, verbose, densmap, densmap_kwds, tqdm_kwds, move_other)
#     398     dens_re_mean = 0
#     399     dens_re_cov = 0
# --> 401 optimize_fn(
#     402     head_embedding,
#     403     tail_embedding,
#     404     head,
#     405     tail,
#     406     n_vertices,
#     407     epochs_per_sample,
#     408     a,
#     409     b,
#     410     rng_state_per_sample,
#     411     gamma,
#     412     dim,
#     413     move_other,
#     414     alpha,
#     415     epochs_per_negative_sample,
#     416     epoch_of_next_negative_sample,
#     417     epoch_of_next_sample,
#     418     n,
#     419     densmap_flag,
#     420     dens_phi_sum,
#     421     dens_re_sum,
#     422     dens_re_cov,
#     423     dens_re_std,
#     424     dens_re_mean,
#     425     dens_lambda,
#     426     dens_R,
#     427     dens_mu,
#     428     dens_mu_tot,
#     429 )
#     431 alpha = initial_alpha * (1.0 - (float(n) / float(n_epochs)))
#     433 if verbose and n % int(n_epochs / 10) == 0:
#
# KeyboardInterrupt:

# %%
def optimize_hdbscan(
    embeddings_array: np.ndarray,
    n_trials: int = 50,
    # n_jobs: int = 8,
    timeout: Optional[int] = None
) -> Dict[str, Any]:
    """
    Optimize HDBSCAN hyperparameters using Optuna.
    
    Args:
        embeddings_array: Normalized embeddings array
        n_trials: Number of optimization trials
        n_jobs: Number of parallel threads for Optuna trials
        timeout: Maximum time in seconds (None for no limit)
    
    Returns:
        Dictionary with best parameters and results
    """
    n_jobs=1
    print(f"Starting optimization with {n_trials} trials, {n_jobs} parallel jobs...")
    print(f"Original embedding shape: {embeddings_array.shape}")
    
    # Create study
    study = optuna.create_study(
        direction='minimize',  # We return negative composite score
        sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE),
        pruner=optuna.pruners.MedianPruner(n_startup_trials=10)
    )
    
    # Use partial instead of lambda (picklable, works with n_jobs)
    # n_jobs uses threading; deadlock is avoided by core_dist_n_jobs=1 in HDBSCAN
    objective = partial(umap_objective, embeddings_array=embeddings_array)
    
    study.optimize(
        objective,
        n_trials=n_trials,
        # n_jobs=n_jobs,
        timeout=timeout,
        show_progress_bar=True
    )
    
    # Get best parameters
    best_params = study.best_params
    best_score = -study.best_value  # Convert back to positive
    
    print(f"\nOptimization completed!")
    print(f"Best composite score: {best_score:.4f}")
    print(f"Best parameters: {best_params}")
    
    # Test best parameters
    print(f"\n=== Results with Best Parameters ===")
        
    best_labels = best_clusterer.fit_predict(best_embeddings)
    best_metrics = calculate_clustering_metrics(best_embeddings, best_labels, best_clusterer)
    
    print_clustering_summary(best_metrics)
    
    # Save results automatically
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    results_file = f"optimization_results_{timestamp}.json"
    
    results_summary = {
        'timestamp': timestamp,
        'best_params': best_params,
        'best_score': float(best_score),
        'best_metrics': {k: float(v) if isinstance(v, (int, float, np.number)) else v 
                         for k, v in best_metrics.items() 
                         if isinstance(v, (int, float, np.number))},
        'n_trials': n_trials,
        'config': {
            'MIN_COMPONENTS': MIN_COMPONENTS,
            'N_TRIALS': N_TRIALS,
            'EMBEDDING_MODEL': EMBEDDING_MODEL,
            'n_samples': len(embeddings_array)
        }
    }
    
    with open(results_file, 'w') as f:
        json.dump(results_summary, f, indent=2)
        
    print(f"\n✓ Results saved to {results_file}\n")
    
    # Return results
    return {
        'study': study,
        'best_params': best_params,
        'best_score': best_score,
        'best_metrics': best_metrics,
    }

# Run optimization
results = optimize_hdbscan(embeddings_array, n_trials=N_TRIALS)
# Out:
# [I 2026-05-20 23:11:26,640] A new study created in memory with name: no-name-63bd92be-cdf5-4957-908b-6d7d97361e0d
# Starting optimization with 100 trials, 1 parallel jobs...
# Original embedding shape: (20000, 3072)
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-05-20 23:13:57,959] Trial 0 finished with value: -0.3016866923729283 and parameters: {'n_components': 193, 'n_neighbors': 48, 'min_dist': 0.36599697090570255, 'min_cluster_size': 7, 'min_samples': 2}. Best is trial 0 with value: -0.3016866923729283.
# [I 2026-05-20 23:15:02,038] Trial 1 finished with value: -0.3945700501469497 and parameters: {'n_components': 86, 'n_neighbors': 12, 'min_dist': 0.4330880728874676, 'min_cluster_size': 7, 'min_samples': 5}. Best is trial 1 with value: -0.3945700501469497.
# [I 2026-05-20 23:19:22,006] Trial 2 finished with value: -0.2847854432750997 and parameters: {'n_components': 20, 'n_neighbors': 49, 'min_dist': 0.41622132040021087, 'min_cluster_size': 3, 'min_samples': 1}. Best is trial 1 with value: -0.3945700501469497.
# [I 2026-05-20 23:20:53,823] Trial 3 finished with value: -0.3756578783719777 and parameters: {'n_components': 100, 'n_neighbors': 22, 'min_dist': 0.2623782158161189, 'min_cluster_size': 5, 'min_samples': 2}. Best is trial 1 with value: -0.3945700501469497.
# [I 2026-05-20 23:23:54,300] Trial 4 finished with value: -0.4567558862846567 and parameters: {'n_components': 310, 'n_neighbors': 15, 'min_dist': 0.14607232426760908, 'min_cluster_size': 5, 'min_samples': 3}. Best is trial 4 with value: -0.4567558862846567.
# [I 2026-05-20 23:27:55,251] Trial 5 finished with value: -0.35203683867842656 and parameters: {'n_components': 395, 'n_neighbors': 18, 'min_dist': 0.2571172192068058, 'min_cluster_size': 7, 'min_samples': 1}. Best is trial 4 with value: -0.4567558862846567.
# [I 2026-05-20 23:30:34,379] Trial 6 finished with value: -0.5232330244741539 and parameters: {'n_components': 308, 'n_neighbors': 16, 'min_dist': 0.03252579649263976, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-20 23:33:40,894] Trial 7 finished with value: -0.4705348887796178 and parameters: {'n_components': 406, 'n_neighbors': 22, 'min_dist': 0.048836057003191935, 'min_cluster_size': 8, 'min_samples': 4}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-20 23:34:41,745] Trial 8 finished with value: -0.455618558658675 and parameters: {'n_components': 69, 'n_neighbors': 30, 'min_dist': 0.017194260557609198, 'min_cluster_size': 10, 'min_samples': 3}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-20 23:39:11,878] Trial 9 finished with value: -0.36684026890311494 and parameters: {'n_components': 335, 'n_neighbors': 22, 'min_dist': 0.2600340105889054, 'min_cluster_size': 6, 'min_samples': 2}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-20 23:44:38,974] Trial 10 finished with value: -0.4626401846879482 and parameters: {'n_components': 478, 'n_neighbors': 38, 'min_dist': 0.12668496424153813, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-20 23:48:25,030] Trial 11 finished with value: -0.5106804218683049 and parameters: {'n_components': 444, 'n_neighbors': 29, 'min_dist': 0.003546058566596757, 'min_cluster_size': 9, 'min_samples': 9}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-20 23:52:12,214] Trial 12 finished with value: -0.47564328487487495 and parameters: {'n_components': 497, 'n_neighbors': 32, 'min_dist': 0.10966253556972158, 'min_cluster_size': 9, 'min_samples': 9}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-20 23:53:43,152] Trial 13 finished with value: -0.5015890057492499 and parameters: {'n_components': 244, 'n_neighbors': 30, 'min_dist': 0.0020981576849260913, 'min_cluster_size': 9, 'min_samples': 7}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-20 23:56:34,225] Trial 14 finished with value: -0.48091354210248816 and parameters: {'n_components': 406, 'n_neighbors': 38, 'min_dist': 0.06988292748653753, 'min_cluster_size': 10, 'min_samples': 8}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-20 23:59:32,389] Trial 15 finished with value: -0.44814383865378044 and parameters: {'n_components': 197, 'n_neighbors': 10, 'min_dist': 0.19222897337573955, 'min_cluster_size': 2, 'min_samples': 2}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-21 00:01:53,645] Trial 16 finished with value: -0.43753049336469874 and parameters: {'n_components': 337, 'n_neighbors': 27, 'min_dist': 0.187848044290508, 'min_cluster_size': 9, 'min_samples': 7}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-21 00:05:29,344] Trial 17 finished with value: -0.45812342919900184 and parameters: {'n_components': 450, 'n_neighbors': 38, 'min_dist': 0.07902133098810966, 'min_cluster_size': 8, 'min_samples': 6}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-21 00:07:28,596] Trial 18 finished with value: -0.39600749727406354 and parameters: {'n_components': 276, 'n_neighbors': 44, 'min_dist': 0.3145390038219683, 'min_cluster_size': 8, 'min_samples': 7}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-21 00:09:52,393] Trial 19 finished with value: -0.3770148622240206 and parameters: {'n_components': 374, 'n_neighbors': 17, 'min_dist': 0.4846349260243588, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-21 00:11:09,221] Trial 20 finished with value: -0.4289391242903837 and parameters: {'n_components': 167, 'n_neighbors': 26, 'min_dist': 0.17289975036178235, 'min_cluster_size': 5, 'min_samples': 4}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-21 00:12:40,292] Trial 21 finished with value: -0.5106401028048195 and parameters: {'n_components': 230, 'n_neighbors': 36, 'min_dist': 0.000999380541048069, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-21 00:14:16,847] Trial 22 finished with value: -0.4942656589730322 and parameters: {'n_components': 256, 'n_neighbors': 33, 'min_dist': 0.03710630315292405, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-21 00:15:50,885] Trial 23 finished with value: -0.5051717044631253 and parameters: {'n_components': 221, 'n_neighbors': 41, 'min_dist': 0.0022896752650033853, 'min_cluster_size': 8, 'min_samples': 8}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-21 00:16:54,594] Trial 24 finished with value: -0.4758628108599642 and parameters: {'n_components': 136, 'n_neighbors': 35, 'min_dist': 0.0858262544733415, 'min_cluster_size': 9, 'min_samples': 9}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-21 00:18:43,934] Trial 25 finished with value: -0.49681844538976294 and parameters: {'n_components': 293, 'n_neighbors': 26, 'min_dist': 0.04882122120024718, 'min_cluster_size': 10, 'min_samples': 9}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-21 00:21:58,409] Trial 26 finished with value: -0.45336713143490615 and parameters: {'n_components': 441, 'n_neighbors': 42, 'min_dist': 0.09165524563086852, 'min_cluster_size': 6, 'min_samples': 5}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-21 00:24:21,455] Trial 27 finished with value: -0.45815329118405257 and parameters: {'n_components': 348, 'n_neighbors': 36, 'min_dist': 0.14451676232456379, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-21 00:25:40,671] Trial 28 finished with value: -0.49977554307444433 and parameters: {'n_components': 228, 'n_neighbors': 19, 'min_dist': 0.040195200622780064, 'min_cluster_size': 8, 'min_samples': 6}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-21 00:27:01,740] Trial 29 finished with value: -0.3958337479767515 and parameters: {'n_components': 166, 'n_neighbors': 45, 'min_dist': 0.2260530375980434, 'min_cluster_size': 7, 'min_samples': 6}. Best is trial 6 with value: -0.5232330244741539.
# [I 2026-05-21 00:28:47,257] Trial 30 finished with value: -0.5240026497525265 and parameters: {'n_components': 311, 'n_neighbors': 14, 'min_dist': 0.029542855514813195, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 30 with value: -0.5240026497525265.
# [I 2026-05-21 00:30:34,173] Trial 31 finished with value: -0.5494767650212127 and parameters: {'n_components': 311, 'n_neighbors': 11, 'min_dist': 0.002965749990136945, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 00:32:14,989] Trial 32 finished with value: -0.5218441259026895 and parameters: {'n_components': 302, 'n_neighbors': 13, 'min_dist': 0.05715057999192576, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 00:34:01,076] Trial 33 finished with value: -0.5257377904715019 and parameters: {'n_components': 315, 'n_neighbors': 13, 'min_dist': 0.05598063886894289, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 00:35:35,519] Trial 34 finished with value: -0.4075908195358118 and parameters: {'n_components': 271, 'n_neighbors': 10, 'min_dist': 0.3538524960912144, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 00:38:38,227] Trial 35 finished with value: -0.4190939953557703 and parameters: {'n_components': 356, 'n_neighbors': 14, 'min_dist': 0.11579265927227955, 'min_cluster_size': 4, 'min_samples': 1}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 00:40:28,591] Trial 36 finished with value: -0.539753664701852 and parameters: {'n_components': 317, 'n_neighbors': 16, 'min_dist': 0.029311665010723662, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 00:42:42,944] Trial 37 finished with value: -0.514667753152862 and parameters: {'n_components': 375, 'n_neighbors': 12, 'min_dist': 0.09313962317600104, 'min_cluster_size': 7, 'min_samples': 7}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 00:44:36,658] Trial 38 finished with value: -0.5126864516579819 and parameters: {'n_components': 322, 'n_neighbors': 20, 'min_dist': 0.03085208018871339, 'min_cluster_size': 10, 'min_samples': 9}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 00:46:12,097] Trial 39 finished with value: -0.4711493838433741 and parameters: {'n_components': 282, 'n_neighbors': 15, 'min_dist': 0.152279060153238, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 00:48:42,488] Trial 40 finished with value: -0.5229352198083628 and parameters: {'n_components': 387, 'n_neighbors': 10, 'min_dist': 0.06935784630856599, 'min_cluster_size': 8, 'min_samples': 7}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 00:50:41,225] Trial 41 finished with value: -0.5389854901033795 and parameters: {'n_components': 310, 'n_neighbors': 17, 'min_dist': 0.029571650967425145, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 00:52:41,159] Trial 42 finished with value: -0.5345002616738272 and parameters: {'n_components': 317, 'n_neighbors': 12, 'min_dist': 0.02793989610302737, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 00:54:58,881] Trial 43 finished with value: -0.5269439760547614 and parameters: {'n_components': 353, 'n_neighbors': 12, 'min_dist': 0.05765504710652832, 'min_cluster_size': 9, 'min_samples': 9}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 00:57:17,886] Trial 44 finished with value: -0.5250191625303663 and parameters: {'n_components': 342, 'n_neighbors': 17, 'min_dist': 0.02246559717632344, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 00:59:18,236] Trial 45 finished with value: -0.42918412352337887 and parameters: {'n_components': 259, 'n_neighbors': 21, 'min_dist': 0.29124934165505906, 'min_cluster_size': 9, 'min_samples': 9}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:02:30,749] Trial 46 finished with value: -0.47850762368561606 and parameters: {'n_components': 422, 'n_neighbors': 23, 'min_dist': 0.1075695280413375, 'min_cluster_size': 10, 'min_samples': 9}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:05:21,709] Trial 47 finished with value: -0.5314587565436323 and parameters: {'n_components': 361, 'n_neighbors': 16, 'min_dist': 0.02525606051560616, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:07:58,975] Trial 48 finished with value: -0.5420851162674429 and parameters: {'n_components': 366, 'n_neighbors': 16, 'min_dist': 0.012631573089461084, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:12:29,043] Trial 49 finished with value: -0.38783162871217564 and parameters: {'n_components': 325, 'n_neighbors': 24, 'min_dist': 0.1308780424410028, 'min_cluster_size': 3, 'min_samples': 1}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:12:53,233] Trial 50 finished with value: -0.5261000524065274 and parameters: {'n_components': 21, 'n_neighbors': 18, 'min_dist': 0.015549640618616753, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:15:20,234] Trial 51 finished with value: -0.5329278104136086 and parameters: {'n_components': 375, 'n_neighbors': 16, 'min_dist': 0.019852465693544583, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:17:49,047] Trial 52 finished with value: -0.5076303782659083 and parameters: {'n_components': 405, 'n_neighbors': 19, 'min_dist': 0.070235827235394, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:20:02,648] Trial 53 finished with value: -0.5425367166749084 and parameters: {'n_components': 384, 'n_neighbors': 16, 'min_dist': 0.010945757410066703, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:21:41,992] Trial 54 finished with value: -0.5297262030940184 and parameters: {'n_components': 295, 'n_neighbors': 12, 'min_dist': 0.047523207755656154, 'min_cluster_size': 10, 'min_samples': 9}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:24:09,750] Trial 55 finished with value: -0.5474110374855912 and parameters: {'n_components': 424, 'n_neighbors': 15, 'min_dist': 0.001649711754697681, 'min_cluster_size': 9, 'min_samples': 9}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:26:38,134] Trial 56 finished with value: -0.5359694056807115 and parameters: {'n_components': 424, 'n_neighbors': 15, 'min_dist': 0.00716016780443144, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:30:16,009] Trial 57 finished with value: -0.31745511717956504 and parameters: {'n_components': 469, 'n_neighbors': 50, 'min_dist': 0.39735498044605294, 'min_cluster_size': 8, 'min_samples': 3}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:32:48,615] Trial 58 finished with value: -0.5230978496932812 and parameters: {'n_components': 418, 'n_neighbors': 21, 'min_dist': 0.001345345928590923, 'min_cluster_size': 9, 'min_samples': 9}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:35:35,490] Trial 59 finished with value: -0.5091058638724062 and parameters: {'n_components': 464, 'n_neighbors': 18, 'min_dist': 0.06778169961032132, 'min_cluster_size': 10, 'min_samples': 10}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:38:31,763] Trial 60 finished with value: -0.5011982625837199 and parameters: {'n_components': 492, 'n_neighbors': 14, 'min_dist': 0.0983656110558421, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:40:47,931] Trial 61 finished with value: -0.5470555068745306 and parameters: {'n_components': 389, 'n_neighbors': 15, 'min_dist': 0.005497963932873707, 'min_cluster_size': 9, 'min_samples': 9}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:43:06,808] Trial 62 finished with value: -0.5274527197558221 and parameters: {'n_components': 390, 'n_neighbors': 17, 'min_dist': 0.03983053163513728, 'min_cluster_size': 10, 'min_samples': 9}. Best is trial 31 with value: -0.5494767650212127.
# [I 2026-05-21 01:44:57,497] Trial 63 finished with value: -0.5521012886021391 and parameters: {'n_components': 332, 'n_neighbors': 10, 'min_dist': 0.015648847390875208, 'min_cluster_size': 9, 'min_samples': 9}. Best is trial 63 with value: -0.5521012886021391.
# [I 2026-05-21 01:47:08,065] Trial 64 finished with value: -0.5622702021851612 and parameters: {'n_components': 370, 'n_neighbors': 11, 'min_dist': 0.0003455236416162778, 'min_cluster_size': 8, 'min_samples': 7}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 01:49:46,840] Trial 65 finished with value: -0.5459032007930023 and parameters: {'n_components': 445, 'n_neighbors': 10, 'min_dist': 0.013762937052925075, 'min_cluster_size': 8, 'min_samples': 7}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 01:52:31,968] Trial 66 finished with value: -0.45801838312220966 and parameters: {'n_components': 431, 'n_neighbors': 10, 'min_dist': 0.22882060971607315, 'min_cluster_size': 7, 'min_samples': 5}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 01:55:15,426] Trial 67 finished with value: -0.5443978669965757 and parameters: {'n_components': 451, 'n_neighbors': 11, 'min_dist': 0.0006716827150223506, 'min_cluster_size': 8, 'min_samples': 6}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 01:58:00,510] Trial 68 finished with value: -0.5225107575691739 and parameters: {'n_components': 454, 'n_neighbors': 11, 'min_dist': 0.046922078516674376, 'min_cluster_size': 8, 'min_samples': 6}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:00:29,858] Trial 69 finished with value: -0.5555242731042196 and parameters: {'n_components': 407, 'n_neighbors': 11, 'min_dist': 0.00033820667962609213, 'min_cluster_size': 8, 'min_samples': 7}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:03:11,156] Trial 70 finished with value: -0.4969272753685978 and parameters: {'n_components': 401, 'n_neighbors': 13, 'min_dist': 0.07727576292291718, 'min_cluster_size': 6, 'min_samples': 4}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:06:11,682] Trial 71 finished with value: -0.543881170820632 and parameters: {'n_components': 443, 'n_neighbors': 11, 'min_dist': 0.0010644985703401743, 'min_cluster_size': 8, 'min_samples': 7}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:09:03,251] Trial 72 finished with value: -0.5422880246563034 and parameters: {'n_components': 476, 'n_neighbors': 11, 'min_dist': 0.01779498405797352, 'min_cluster_size': 8, 'min_samples': 6}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:11:33,937] Trial 73 finished with value: -0.5300827241267647 and parameters: {'n_components': 413, 'n_neighbors': 10, 'min_dist': 0.04609107741058649, 'min_cluster_size': 7, 'min_samples': 6}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:14:20,282] Trial 74 finished with value: -0.5436915007427987 and parameters: {'n_components': 457, 'n_neighbors': 13, 'min_dist': 0.0017378164649625115, 'min_cluster_size': 8, 'min_samples': 7}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:17:00,944] Trial 75 finished with value: -0.4979238909079267 and parameters: {'n_components': 434, 'n_neighbors': 14, 'min_dist': 0.05781795858875872, 'min_cluster_size': 7, 'min_samples': 5}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:19:57,972] Trial 76 finished with value: -0.5437070607640455 and parameters: {'n_components': 485, 'n_neighbors': 11, 'min_dist': 0.034891847611590934, 'min_cluster_size': 8, 'min_samples': 7}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:22:04,459] Trial 77 finished with value: -0.39398962637882007 and parameters: {'n_components': 335, 'n_neighbors': 12, 'min_dist': 0.4895000226481788, 'min_cluster_size': 8, 'min_samples': 7}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:24:32,008] Trial 78 finished with value: -0.522241303459379 and parameters: {'n_components': 412, 'n_neighbors': 14, 'min_dist': 0.01686027433494285, 'min_cluster_size': 7, 'min_samples': 5}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:27:28,455] Trial 79 finished with value: -0.5330971903650236 and parameters: {'n_components': 500, 'n_neighbors': 10, 'min_dist': 0.039602763378085756, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:29:48,008] Trial 80 finished with value: -0.5217966114352426 and parameters: {'n_components': 392, 'n_neighbors': 13, 'min_dist': 0.016889479753945582, 'min_cluster_size': 8, 'min_samples': 6}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:32:28,430] Trial 81 finished with value: -0.5561243823659894 and parameters: {'n_components': 445, 'n_neighbors': 11, 'min_dist': 0.0002995058310690489, 'min_cluster_size': 8, 'min_samples': 7}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:35:05,978] Trial 82 finished with value: -0.5370049473734946 and parameters: {'n_components': 439, 'n_neighbors': 11, 'min_dist': 0.010373127083121483, 'min_cluster_size': 9, 'min_samples': 7}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:37:48,053] Trial 83 finished with value: -0.5228070597149089 and parameters: {'n_components': 451, 'n_neighbors': 15, 'min_dist': 0.03111827829742758, 'min_cluster_size': 8, 'min_samples': 7}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:40:16,417] Trial 84 finished with value: -0.5034358298074786 and parameters: {'n_components': 400, 'n_neighbors': 12, 'min_dist': 0.05942511486691212, 'min_cluster_size': 6, 'min_samples': 4}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:42:23,530] Trial 85 finished with value: -0.5344819311863427 and parameters: {'n_components': 365, 'n_neighbors': 10, 'min_dist': 0.022486808825697178, 'min_cluster_size': 9, 'min_samples': 6}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:44:57,872] Trial 86 finished with value: -0.5453280004679617 and parameters: {'n_components': 430, 'n_neighbors': 13, 'min_dist': 0.0006973385662886967, 'min_cluster_size': 8, 'min_samples': 7}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:47:34,239] Trial 87 finished with value: -0.5006154864252336 and parameters: {'n_components': 428, 'n_neighbors': 13, 'min_dist': 0.08280944002312535, 'min_cluster_size': 7, 'min_samples': 6}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:49:41,950] Trial 88 finished with value: -0.5107609206328876 and parameters: {'n_components': 372, 'n_neighbors': 14, 'min_dist': 0.04107000615651818, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:51:49,563] Trial 89 finished with value: -0.38342204595583046 and parameters: {'n_components': 353, 'n_neighbors': 15, 'min_dist': 0.45943291009912735, 'min_cluster_size': 8, 'min_samples': 7}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:53:44,634] Trial 90 finished with value: -0.5464456981149469 and parameters: {'n_components': 340, 'n_neighbors': 13, 'min_dist': 0.013011779959194671, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:55:34,857] Trial 91 finished with value: -0.536249550130658 and parameters: {'n_components': 328, 'n_neighbors': 13, 'min_dist': 0.015094209469703624, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:57:48,092] Trial 92 finished with value: -0.5355510091998004 and parameters: {'n_components': 381, 'n_neighbors': 12, 'min_dist': 0.027672123215683124, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 02:59:45,576] Trial 93 finished with value: -0.547690131161035 and parameters: {'n_components': 342, 'n_neighbors': 10, 'min_dist': 0.010777540723159621, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 03:01:46,307] Trial 94 finished with value: -0.5330923180309272 and parameters: {'n_components': 346, 'n_neighbors': 10, 'min_dist': 0.05030215052048349, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 03:03:44,413] Trial 95 finished with value: -0.537347667163824 and parameters: {'n_components': 336, 'n_neighbors': 11, 'min_dist': 0.011925263395815521, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 03:05:51,526] Trial 96 finished with value: -0.5126315648984466 and parameters: {'n_components': 356, 'n_neighbors': 12, 'min_dist': 0.06544754748292408, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 03:07:49,614] Trial 97 finished with value: -0.5134078695704226 and parameters: {'n_components': 283, 'n_neighbors': 11, 'min_dist': 0.037394816162378365, 'min_cluster_size': 5, 'min_samples': 3}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 03:10:13,548] Trial 98 finished with value: -0.5457189021459957 and parameters: {'n_components': 409, 'n_neighbors': 10, 'min_dist': 0.023726337099327227, 'min_cluster_size': 9, 'min_samples': 8}. Best is trial 64 with value: -0.5622702021851612.
# [I 2026-05-21 03:12:07,004] Trial 99 finished with value: -0.5050496604378156 and parameters: {'n_components': 300, 'n_neighbors': 29, 'min_dist': 0.010504134367747843, 'min_cluster_size': 8, 'min_samples': 7}. Best is trial 64 with value: -0.5622702021851612.
#
# Optimization completed!
# Best composite score: 0.5623
# Best parameters: {'n_components': 370, 'n_neighbors': 11, 'min_dist': 0.0003455236416162778, 'min_cluster_size': 8, 'min_samples': 7}
#
# === Results with Best Parameters ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 92
#      84     return {
#      85         'study': study,
#      86         'best_params': best_params,
#      87         'best_score': best_score,
#      88         'best_metrics': best_metrics,
#      89     }
#      91 # Run optimization
# ---> 92 results = optimize_hdbscan(embeddings_array, n_trials=N_TRIALS)
#
# Cell In[20], line 53, in optimize_hdbscan(embeddings_array, n_trials, timeout)
#      50 # Test best parameters
#      51 print(f"\n=== Results with Best Parameters ===")
# ---> 53 best_labels = best_clusterer.fit_predict(best_embeddings)
#      54 best_metrics = calculate_clustering_metrics(best_embeddings, best_labels, best_clusterer)
#      56 print_clustering_summary(best_metrics)
#
# NameError: name 'best_clusterer' is not defined

# %%
# Plot optimization history
try:
    import plotly.graph_objects as go
    
    trials = results['study'].trials
    values = [-t.value for t in trials if t.value is not None]  # Convert back to positive
    trial_numbers = list(range(1, len(values) + 1))
    
    # Create plot
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=trial_numbers,
        y=values,
        mode='lines+markers',
        name='Composite Score',
        line=dict(color='blue', width=2),
        marker=dict(size=4)
    ))
    
    # Add best score line
    best_score = max(values)
    fig.add_hline(y=best_score, line_dash="dash", line_color="red",
                 annotation_text=f"Best: {best_score:.4f}")
    
    fig.update_layout(
        title='HDBSCAN Optimization History',
        xaxis_title='Trial',
        yaxis_title='Composite Score',
        showlegend=True
    )
    
    fig.show()
    
except ImportError:
    print("Install plotly to visualize optimization history: pip install plotly")

# %%
with open(sorted(glob.glob('optimization_results_*.json'))[-1], 'r') as f:
  best_params = json.load(f)['best_params']

# %%
best_params

# %%
# Display best metrics
print("Best Silhouette Score:", results['best_metrics'].get('silhouette_score', 'N/A'))
print("Best Composite Score:", results['best_metrics'].get('composite_score', 'N/A'))
print("\nBest Parameters:")
for key, value in results['best_params'].items():
    print(f"  {key}: {value}")

# %%
# Display best metrics
print("Best Silhouette Score:", results['best_metrics'].get('silhouette_score', 'N/A'))
print("Best Composite Score:", results['best_metrics'].get('composite_score', 'N/A'))
print("\nBest Parameters:")
for key, value in results['best_params'].items():
    print(f"  {key}: {value}")

# %%
# Save the UMAP reducer for reuse
# best_params = results['best_params']

umap_reducer = umap.UMAP(
        n_components=best_params['n_components'],
        n_neighbors=best_params['n_neighbors'],
        min_dist=best_params['min_dist'],
        random_state=RANDOM_STATE
    )

reduced_embeddings = umap_reducer.fit_transform(embeddings_array).astype(np.float64)

with open('umap_reducer.pkl', 'wb') as f:
    pickle.dump(umap_reducer, f)
print("✓ Saved UMAP reducer to umap_reducer.pkl")

# %%
new_summaries = headline_df["input_text"].sample(n=min(100, len(headline_df)), random_state=RANDOM_STATE).to_list()

# %%
# run on a new list of short summaries
with open('umap_reducer.pkl', 'rb') as f:
  umap_reducer = pickle.load(f)

# Load params from most recent file
with open(sorted(glob.glob('optimization_results_*.json'))[-1], 'r') as f:
  params = json.load(f)['best_params']

# Generate embeddings
client = openai.OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
resp = client.embeddings.create(
  model="text-embedding-3-large",
  input=new_summaries
)
embeddings = np.array([d.embedding for d in resp.data])

# Reduce dimensions
reduced = umap_reducer.transform(embeddings).astype(np.float64)

# Cluster
clusterer = hdbscan.HDBSCAN(
  min_cluster_size=params['min_cluster_size'],
  min_samples=params['min_samples'],
  metric="euclidean",
  cluster_selection_method="eom"
)

labels = clusterer.fit_predict(reduced)
